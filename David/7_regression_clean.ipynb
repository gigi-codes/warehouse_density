# %% [markdown]
# # 7 Linear Regression Models
#
# 4/27/22
#
# This notebook uses the final processed data set, consisting of the California Enviroscans 1 through 4, and the warehouse business census counts for each zip code.
#
# - [Import libraries](#Import-libraries)
# - [Import and examine merged CAES and business count data.](#Import-and-examine-merged-CAES-and-business-count-data.)

# %% [markdown]
# ## Initial setup
#
# ### Import libraries

# %%
import os
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import and examine merged CAES and business count data.

# %%
#import the merged CAESes 1-4 and business-counts-by-zip data 
all_merged_filepath = '../processed_data/all_merged.csv'
#amgd -- all merged dataframe
amgd = pd.read_csv(all_merged_filepath)
amgd.head()
# Out:
#      zip  total population     ozone  ozone pctl  pm2.5  pm2.5 pctl  \
# 0  93706             41087  0.177311       76.55  15.61       95.96
# 1  93307             82658  0.512336       93.70  19.40       99.69
# 2  95205             38069  0.022790       38.53  12.51       71.65
# 3  93702             48607  0.317831       86.99  16.08       97.06
# 4  90058              3223  0.015613       31.32  15.26       94.98
#
#    diesel pm  diesel pm pctl  pesticides  pesticides pctl  ...  \
# 0       6.14           56.19     1120.30            90.59  ...
# 1       9.57           64.73     7128.70            98.37  ...
# 2      18.95           80.50       94.20            72.24  ...
# 3      36.85           94.91        7.92            53.79  ...
# 4      56.80           98.36        0.00             0.00  ...
#
#    cardiovascular disease  cardiovascular disease pctl  housing burden  \
# 0                     NaN                          NaN             NaN
# 1                     NaN                          NaN             NaN
# 2                     NaN                          NaN             NaN
# 3                     NaN                          NaN             NaN
# 4                     NaN                          NaN             NaN
#
#    housing burden pctl  census_year  est total  est gen  est cold  est farm  \
# 0                  NaN         2012          4        4         0         0
# 1                  NaN         2012          1        0         0         1
# 2                  NaN         2012          1        0         0         0
# 3                  NaN         2012          0        0         0         0
# 4                  NaN         2012         35       12        19         0
#
#    est other
# 0          0
# 1          0
# 2          1
# 3          0
# 4          4
#
# [5 rows x 63 columns]

# %%
#look at the data included with the imported file.
amgd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25444 entries, 0 to 25443
# Data columns (total 63 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   zip                          25444 non-null  int64
#  1   total population             25444 non-null  int64
#  2   ozone                        25333 non-null  float64
#  3   ozone pctl                   25333 non-null  float64
#  4   pm2.5                        25286 non-null  float64
#  5   pm2.5 pctl                   25286 non-null  float64
#  6   diesel pm                    25444 non-null  float64
#  7   diesel pm pctl               25444 non-null  float64
#  8   pesticides                   25444 non-null  float64
#  9   pesticides pctl              25444 non-null  float64
#  10  traffic                      25353 non-null  float64
#  11  traffic pctl                 25353 non-null  float64
#  12  cleanup sites                25444 non-null  float64
#  13  cleanup sites pctl           25444 non-null  float64
#  14  groundwater threats          25444 non-null  float64
#  15  groundwater threats pctl     25444 non-null  float64
#  16  haz. waste                   25444 non-null  float64
#  17  haz. waste pctl              25444 non-null  float64
#  18  imp. water bodies            25444 non-null  int64
#  19  imp. water bodies pctl       25444 non-null  float64
#  20  solid waste                  25444 non-null  float64
#  21  solid waste pctl             25444 non-null  float64
#  22  pollution burden             25444 non-null  float64
#  23  pollution burden score       25444 non-null  float64
#  24  asthma                       25423 non-null  float64
#  25  asthma pctl                  25423 non-null  float64
#  26  low birth weight             24818 non-null  float64
#  27  low birth weight pctl        24818 non-null  float64
#  28  education                    25119 non-null  float64
#  29  education pctl               25119 non-null  float64
#  30  linguistic isolation         24401 non-null  float64
#  31  linguistic isolation pctl    24401 non-null  float64
#  32  poverty                      25159 non-null  float64
#  33  poverty pctl                 25159 non-null  float64
#  34  pop. char.                   25170 non-null  float64
#  35  pop. char. score             25170 non-null  float64
#  36  ces_score                    25170 non-null  float64
#  37  ces_per_range                25170 non-null  object
#  38  year                         25444 non-null  int64
#  39  census tract                 24105 non-null  float64
#  40  county                       24105 non-null  object
#  41  drinking water               24024 non-null  float64
#  42  drinking water pctl          24024 non-null  float64
#  43  tox. release                 24093 non-null  float64
#  44  tox. release pctl            24093 non-null  float64
#  45  pollution burden pctl        24105 non-null  float64
#  46  unemployment                 23434 non-null  float64
#  47  unemployment pctl            23434 non-null  float64
#  48  pop. char. pctl              23834 non-null  float64
#  49  city                         24105 non-null  object
#  50  latitude                     24105 non-null  float64
#  51  longitude                    24105 non-null  float64
#  52  ces_per                      15861 non-null  float64
#  53  cardiovascular disease       16059 non-null  float64
#  54  cardiovascular disease pctl  16059 non-null  float64
#  55  housing burden               15768 non-null  float64
#  56  housing burden pctl          15768 non-null  float64
#  57  census_year                  25444 non-null  int64
#  58  est total                    25444 non-null  int64
#  59  est gen                      25444 non-null  int64
#  60  est cold                     25444 non-null  int64
#  61  est farm                     25444 non-null  int64
#  62  est other                    25444 non-null  int64
# dtypes: float64(50), int64(10), object(3)
# memory usage: 12.2+ MB

# %%
# look at basic statistics of the numerical types.
# ces-per-range, county, and city are non-numerical and excluded here
# the 'zip' statistics have little meaning --- they are just region labels.
amgd.describe()
# Out:
#                 zip  total population         ozone    ozone pctl  \
# count  25444.000000      25444.000000  25333.000000  25333.000000
# mean   92864.446156       5917.335796      0.068468     47.320326
# std     3380.897400       7251.318591      0.112443     30.957227
# min       32.000000          0.000000      0.000000      0.000000
# 25%    91606.000000       3423.750000      0.030640     20.650000
# 50%    92703.000000       4556.000000      0.045884     48.450529
# 75%    94564.000000       5946.000000      0.059387     73.930000
# max    96161.000000     105549.000000      1.285954    100.000000
#
#               pm2.5    pm2.5 pctl     diesel pm  diesel pm pctl    pesticides  \
# count  25286.000000  25286.000000  25444.000000    25444.000000  25444.000000
# mean      10.221574     51.367337     12.497526       50.444645    296.028216
# std        2.503114     29.032522     16.249286       28.787606   2555.276827
# min        1.651081      0.010000      0.000000        0.000000      0.000000
# 25%        8.559432     27.690338      0.000898       25.672060      0.000000
# 50%       10.370000     52.610000      7.650000       50.667918      0.000000
# 75%       12.050000     77.977844     19.760000       75.400000      0.488285
# max       21.200000    100.000000    253.731000      100.000000  91316.190000
#
#        pesticides pctl  ...  cardiovascular disease  \
# count     25444.000000  ...            16059.000000
# mean         18.939449  ...               10.837837
# std          30.078159  ...                4.953450
# min           0.000000  ...                0.000000
# 25%           0.000000  ...                7.265000
# 50%           0.000000  ...                9.760000
# 75%          34.110000  ...               13.320000
# max         100.000000  ...               40.850000
#
#        cardiovascular disease pctl  housing burden  housing burden pctl  \
# count                 16059.000000    15768.000000         15768.000000
# mean                     50.011075       18.908923            50.184404
# std                      28.891888        8.509076            28.835873
# min                       0.000000        0.800000             0.012674
# 25%                      25.000000       12.600000            25.323194
# 50%                      50.024925       17.600000            50.266160
# 75%                      75.070000       23.900000            75.107731
# max                     100.000000       78.200000           100.000000
#
#         census_year     est total       est gen      est cold      est farm  \
# count  25444.000000  25444.000000  25444.000000  25444.000000  25444.000000
# mean    2013.578958      1.959047      1.468716      0.181222      0.028730
# std        0.590788      5.277823      4.470229      0.757449      0.182993
# min     2012.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2013.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2014.000000      0.000000      0.000000      0.000000      0.000000
# 75%     2014.000000      2.000000      1.000000      0.000000      0.000000
# max     2014.000000     96.000000     86.000000     19.000000      3.000000
#
#           est other
# count  25444.000000
# mean       0.280380
# std        0.718911
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        9.000000
#
# [8 rows x 60 columns]

# %% [markdown]
# ### Remove percentile columns.

# %% [markdown]
# ### Extract numeric columns for linear regressions.

# %%
numeric_cols =

# %% [markdown]
# ### Inpute missing values.

# %%
amgd.fillna(amgd.median())
# Out:
# C:\Users\David\AppData\Local\Temp/ipykernel_9848/2540411249.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   amgd.fillna(amgd.median())
#          zip  total population     ozone  ozone pctl      pm2.5  pm2.5 pctl  \
# 0      93706             41087  0.177311   76.550000  15.610000   95.960000
# 1      93307             82658  0.512336   93.700000  19.400000   99.690000
# 2      95205             38069  0.022790   38.530000  12.510000   71.650000
# 3      93702             48607  0.317831   86.990000  16.080000   97.060000
# 4      90058              3223  0.015613   31.320000  15.260000   94.980000
# ...      ...               ...       ...         ...        ...         ...
# 25439  92140              3760  0.042599   29.894213  10.270812   50.914748
# 25440  92135              2467  0.042599   29.894213  10.463289   52.283759
# 25441  94128                 0  0.034190   10.566273   8.789373   32.619788
# 25442     57                10  0.039421   17.672682   7.052988    6.994400
# 25443     61               118  0.042599   29.894213   5.915569    2.874922
#
#        diesel pm  diesel pm pctl  pesticides  pesticides pctl  ...  \
# 0       6.140000       56.190000     1120.30            90.59  ...
# 1       9.570000       64.730000     7128.70            98.37  ...
# 2      18.950000       80.500000       94.20            72.24  ...
# 3      36.850000       94.910000        7.92            53.79  ...
# 4      56.800000       98.360000        0.00             0.00  ...
# ...          ...             ...         ...              ...  ...
# 25439   0.000952       80.883634        0.00             0.00  ...
# 25440   0.000576       63.932794        0.00             0.00  ...
# 25441   0.002846       98.382078        0.00             0.00  ...
# 25442   0.000007        1.008090        0.00             0.00  ...
# 25443   0.000009        1.431238        0.00             0.00  ...
#
#        cardiovascular disease  cardiovascular disease pctl  housing burden  \
# 0                        9.76                    50.024925            17.6
# 1                        9.76                    50.024925            17.6
# 2                        9.76                    50.024925            17.6
# 3                        9.76                    50.024925            17.6
# 4                        9.76                    50.024925            17.6
# ...                       ...                          ...             ...
# 25439                    7.98                    13.659023            17.6
# 25440                    3.73                     0.024925            17.6
# 25441                    9.76                    50.024925            17.6
# 25442                    8.59                    17.896311            17.6
# 25443                   15.21                    67.696909            17.6
#
#        housing burden pctl  census_year  est total  est gen  est cold  \
# 0                 50.26616         2012          4        4         0
# 1                 50.26616         2012          1        0         0
# 2                 50.26616         2012          1        0         0
# 3                 50.26616         2012          0        0         0
# 4                 50.26616         2012         35       12        19
# ...                    ...          ...        ...      ...       ...
# 25439             50.26616         2014          0        0         0
# 25440             50.26616         2014          0        0         0
# 25441             50.26616         2014          0        0         0
# 25442             50.26616         2014          0        0         0
# 25443             50.26616         2014          0        0         0
#
#        est farm  est other
# 0             0          0
# 1             1          0
# 2             0          1
# 3             0          0
# 4             0          4
# ...         ...        ...
# 25439         0          0
# 25440         0          0
# 25441         0          0
# 25442         0          0
# 25443         0          0
#
# [25444 rows x 63 columns]

# %%
amgd.median()
# Out:
# C:\Users\David\AppData\Local\Temp/ipykernel_9848/1629679674.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   amgd.median()
# zip                            9.270300e+04
# total population               4.556000e+03
# ozone                          4.588368e-02
# ozone pctl                     4.845053e+01
# pm2.5                          1.037000e+01
# pm2.5 pctl                     5.261000e+01
# diesel pm                      7.650000e+00
# diesel pm pctl                 5.066792e+01
# pesticides                     0.000000e+00
# pesticides pctl                0.000000e+00
# traffic                        8.143707e+02
# traffic pctl                   5.060000e+01
# cleanup sites                  2.250000e+00
# cleanup sites pctl             2.749160e+01
# groundwater threats            7.600000e+00
# groundwater threats pctl       3.638000e+01
# haz. waste                     1.300000e-01
# haz. waste pctl                3.919000e+01
# imp. water bodies              1.000000e+00
# imp. water bodies pctl         1.526000e+01
# solid waste                    2.000000e-01
# solid waste pctl               3.620000e+00
# pollution burden               4.181321e+01
# pollution burden score         5.059583e+00
# asthma                         4.268000e+01
# asthma pctl                    4.989000e+01
# low birth weight               5.067230e+00
# low birth weight pctl          5.016000e+01
# education                      1.390000e+01
# education pctl                 5.000000e+01
# linguistic isolation           7.300000e+00
# linguistic isolation pctl      4.819326e+01
# poverty                        3.092202e+01
# poverty pctl                   4.994000e+01
# pop. char.                     4.962261e+01
# pop. char. score               5.138454e+00
# ces_score                      2.443268e+01
# year                           2.018000e+03
# census tract                   6.059053e+09
# drinking water                 4.113764e+02
# drinking water pctl            5.041419e+01
# tox. release                   4.175217e+02
# tox. release pctl              4.989000e+01
# pollution burden pctl          5.001000e+01
# unemployment                   8.310000e+00
# unemployment pctl              5.027000e+01
# pop. char. pctl                5.001000e+01
# latitude                       3.420662e+01
# longitude                     -1.184292e+02
# ces_per                        5.001000e+01
# cardiovascular disease         9.760000e+00
# cardiovascular disease pctl    5.002493e+01
# housing burden                 1.760000e+01
# housing burden pctl            5.026616e+01
# census_year                    2.014000e+03
# est total                      0.000000e+00
# est gen                        0.000000e+00
# est cold                       0.000000e+00
# est farm                       0.000000e+00
# est other                      0.000000e+00
# dtype: float64

# %% [markdown]
# ### Assign a label for target columns
#
# These columns are the primary targets later in this notebook.

# %%
health_cols = ['asthma', #a
               'low birth weight', #b
              'cardiovascular disease' #c
              ]

# %% [markdown]
# ## Linear regressions on time and space features.
#
# The analysis later on primarily ignores these features. There are a general general relationships we can draw by looking at them.

# %%
time_space_cols = ['year',
                  'latitude',
                  'longitude'
                  ]

# %%
X = amgd

# %%
lr_time_space_a = LinearRegression()
lr_time_space_a.fit
