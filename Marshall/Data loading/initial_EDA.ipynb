# %%
import json
import urllib.request
url = 'https://data.ca.gov/api/3/action/datastore_search?resource_id=89b3f4e9-0bf8-4690-8c6f-715a717f3fae&limit=5&q=title:jones'  
fileobj = urllib.request.urlopen(url)
response_dict = json.loads(fileobj.read())
print(response_dict)
# Out:
# {'help': 'https://data.ca.gov/api/3/action/help_show?name=datastore_search', 'success': True, 'result': {'include_total': True, 'resource_id': '89b3f4e9-0bf8-4690-8c6f-715a717f3fae', 'fields': [{'type': 'int', 'id': '_id'}, {'type': 'text', 'id': 'Census Tract'}, {'type': 'text', 'id': 'Total Population'}, {'type': 'text', 'id': 'California County'}, {'type': 'text', 'id': 'ZIP'}, {'type': 'text', 'id': 'Nearby City \n(to help approximate location only)'}, {'type': 'text', 'id': 'Longitude'}, {'type': 'text', 'id': 'Latitude'}, {'type': 'text', 'id': 'CES 3.0 Score'}, {'type': 'text', 'id': 'CES 3.0 Percentile'}, {'type': 'text', 'id': 'CES 3.0 \nPercentile Range'}, {'type': 'text', 'id': 'SB 535 Disadvantaged Community'}, {'type': 'text', 'id': 'Ozone'}, {'type': 'text', 'id': 'Ozone Pctl'}, {'type': 'text', 'id': 'PM2.5'}, {'type': 'text', 'id': 'PM2.5 Pctl'}, {'type': 'text', 'id': 'Diesel PM'}, {'type': 'text', 'id': 'Diesel PM Pctl'}, {'type': 'text', 'id': 'Drinking Water'}, {'type': 'text', 'id': 'Drinking Water Pctl'}, {'type': 'text', 'id': 'Pesticides'}, {'type': 'text', 'id': 'Pesticides Pctl'}, {'type': 'text', 'id': 'Tox. Release'}, {'type': 'text', 'id': 'Tox. Release Pctl'}, {'type': 'text', 'id': 'Traffic'}, {'type': 'text', 'id': 'Traffic Pctl'}, {'type': 'text', 'id': 'Cleanup Sites'}, {'type': 'text', 'id': 'Cleanup Sites Pctl'}, {'type': 'text', 'id': 'Groundwater Threats'}, {'type': 'text', 'id': 'Groundwater Threats Pctl'}, {'type': 'text', 'id': 'Haz. Waste'}, {'type': 'text', 'id': 'Haz. Waste Pctl'}, {'type': 'text', 'id': 'Imp. Water Bodies'}, {'type': 'text', 'id': 'Imp. Water Bodies Pctl'}, {'type': 'text', 'id': 'Solid Waste'}, {'type': 'text', 'id': 'Solid Waste Pctl'}, {'type': 'text', 'id': 'Pollution Burden'}, {'type': 'text', 'id': 'Pollution Burden Score'}, {'type': 'text', 'id': 'Pollution Burden Pctl'}, {'type': 'text', 'id': 'Asthma'}, {'type': 'text', 'id': 'Asthma Pctl'}, {'type': 'text', 'id': 'Low Birth Weight'}, {'type': 'text', 'id': 'Low Birth Weight Pctl'}, {'type': 'text', 'id': 'Cardiovascular Disease'}, {'type': 'text', 'id': 'Cardiovascular Disease Pctl'}, {'type': 'text', 'id': 'Education'}, {'type': 'text', 'id': 'Education Pctl'}, {'type': 'text', 'id': 'Linguistic Isolation'}, {'type': 'text', 'id': 'Linguistic Isolation Pctl'}, {'type': 'text', 'id': 'Poverty'}, {'type': 'text', 'id': 'Poverty Pctl'}, {'type': 'text', 'id': 'Unemployment'}, {'type': 'text', 'id': 'Unemployment Pctl'}, {'type': 'text', 'id': 'Housing Burden'}, {'type': 'text', 'id': 'Housing Burden Pctl'}, {'type': 'text', 'id': 'Pop. Char.'}, {'type': 'text', 'id': 'Pop. Char. Score'}, {'type': 'text', 'id': 'Pop. Char. Pctl'}, {'type': 'float', 'id': 'rank'}], 'records_format': 'objects', 'q': 'title:jones', 'records': [], 'limit': 5, '_links': {'start': '/api/3/action/datastore_search?q=title%3Ajones&limit=5&resource_id=89b3f4e9-0bf8-4690-8c6f-715a717f3fae', 'next': '/api/3/action/datastore_search?q=title%3Ajones&offset=5&limit=5&resource_id=89b3f4e9-0bf8-4690-8c6f-715a717f3fae'}, 'total': 0}}

# %%
import pandas as pd

# %%
cal = pd.read_csv('https://data.ca.gov/dataset/0bd5f40b-c59b-4183-be22-d057eae8383c/resource/89b3f4e9-0bf8-4690-8c6f-715a717f3fae/download/calenviroscreen-3.0-results-june-2018-update.csv')

# %%
cal.head()
# Out:
#    Census Tract  Total Population California County    ZIP  \
# 0    6019001100              3174           Fresno   93706
# 1    6071001600              6133    San Bernardino  91761
# 2    6019000200              3167           Fresno   93706
# 3    6077000801              6692       San Joaquin  95203
# 4    6019001500              2206           Fresno   93725
#
#   Nearby City \n(to help approximate location only)   Longitude   Latitude  \
# 0                                            Fresno -119.781696  36.709695
# 1                                           Ontario -117.618013  34.057780
# 2                                            Fresno -119.805504  36.735491
# 3                                          Stockton -121.314524  37.940517
# 4                                            Fresno -119.717843  36.681600
#
#    CES 3.0 Score   CES 3.0 Percentile CES 3.0 \nPercentile Range  ...  \
# 0          94.09               100.00   95-100% (highest scores)  ...
# 1          90.68                99.99   95-100% (highest scores)  ...
# 2          85.97                99.97   95-100% (highest scores)  ...
# 3          82.49                99.96   95-100% (highest scores)  ...
# 4          82.03                99.95   95-100% (highest scores)  ...
#
#   Linguistic Isolation Pctl  Poverty  Poverty Pctl  Unemployment  \
# 0                     77.51     76.3         97.12          17.6
# 1                     96.25     72.5         94.63          12.3
# 2                     78.39     86.8         99.56          16.1
# 3                     75.14     61.3         85.57          19.6
# 4                     73.72     66.4         90.23          18.6
#
#    Unemployment Pctl  Housing Burden  Housing Burden Pctl  Pop. Char.   \
# 0              91.72            26.0                79.40        92.12
# 1              71.82            34.1                93.75        87.44
# 2              87.98            40.1                97.85        94.58
# 3              94.97            21.1                63.54        86.70
# 4              93.65            28.1                83.98        80.08
#
#    Pop. Char. Score  Pop. Char. Pctl
# 0              9.55            99.70
# 1              9.07            98.11
# 2              9.81            99.99
# 3              8.99            97.72
# 4              8.30            92.76
#
# [5 rows x 57 columns]

# %%
cal.isnull().sum()
# Out:
# Census Tract                                           0
# Total Population                                       0
# California County                                      0
# ZIP                                                    0
# Nearby City \n(to help approximate location only)      0
# Longitude                                              0
# Latitude                                               0
# CES 3.0 Score                                        106
#  CES 3.0 Percentile                                  106
# CES 3.0 \nPercentile Range                           106
# SB 535 Disadvantaged Community                         0
# Ozone                                                  0
# Ozone Pctl                                             0
# PM2.5                                                 19
# PM2.5 Pctl                                            19
# Diesel PM                                              0
# Diesel PM Pctl                                         0
# Drinking Water                                        18
# Drinking Water Pctl                                   18
# Pesticides                                             0
# Pesticides Pctl                                        0
# Tox. Release                                           0
# Tox. Release Pctl                                      0
# Traffic                                               56
# Traffic Pctl                                          56
# Cleanup Sites                                          0
# Cleanup Sites Pctl                                     0
# Groundwater Threats                                    0
# Groundwater Threats Pctl                               0
# Haz. Waste                                             0
# Haz. Waste Pctl                                        0
# Imp. Water Bodies                                      0
# Imp. Water Bodies Pctl                                 0
# Solid Waste                                            0
# Solid Waste Pctl                                       0
# Pollution Burden                                       0
# Pollution Burden Score                                 0
# Pollution Burden Pctl                                  0
# Asthma                                                 0
# Asthma Pctl                                            0
# Low Birth Weight                                     222
# Low Birth Weight Pctl                                222
# Cardiovascular Disease                                 0
# Cardiovascular Disease Pctl                            0
# Education                                             96
# Education Pctl                                        96
# Linguistic Isolation                                 242
# Linguistic Isolation Pctl                            242
# Poverty                                               79
# Poverty Pctl                                          79
# Unemployment                                         155
# Unemployment Pctl                                    155
# Housing Burden                                       157
# Housing Burden Pctl                                  157
# Pop. Char.                                           106
# Pop. Char. Score                                     106
# Pop. Char. Pctl                                      106
# dtype: int64

# %%
cal.dtypes
# Out:
# Census Tract                                           int64
# Total Population                                       int64
# California County                                     object
# ZIP                                                    int64
# Nearby City \n(to help approximate location only)     object
# Longitude                                            float64
# Latitude                                             float64
# CES 3.0 Score                                        float64
#  CES 3.0 Percentile                                  float64
# CES 3.0 \nPercentile Range                            object
# SB 535 Disadvantaged Community                        object
# Ozone                                                float64
# Ozone Pctl                                           float64
# PM2.5                                                float64
# PM2.5 Pctl                                           float64
# Diesel PM                                            float64
# Diesel PM Pctl                                       float64
# Drinking Water                                       float64
# Drinking Water Pctl                                  float64
# Pesticides                                           float64
# Pesticides Pctl                                      float64
# Tox. Release                                         float64
# Tox. Release Pctl                                    float64
# Traffic                                              float64
# Traffic Pctl                                         float64
# Cleanup Sites                                        float64
# Cleanup Sites Pctl                                   float64
# Groundwater Threats                                  float64
# Groundwater Threats Pctl                             float64
# Haz. Waste                                           float64
# Haz. Waste Pctl                                      float64
# Imp. Water Bodies                                      int64
# Imp. Water Bodies Pctl                               float64
# Solid Waste                                          float64
# Solid Waste Pctl                                     float64
# Pollution Burden                                     float64
# Pollution Burden Score                               float64
# Pollution Burden Pctl                                float64
# Asthma                                               float64
# Asthma Pctl                                          float64
# Low Birth Weight                                     float64
# Low Birth Weight Pctl                                float64
# Cardiovascular Disease                               float64
# Cardiovascular Disease Pctl                          float64
# Education                                            float64
# Education Pctl                                       float64
# Linguistic Isolation                                 float64
# Linguistic Isolation Pctl                            float64
# Poverty                                              float64
# Poverty Pctl                                         float64
# Unemployment                                         float64
# Unemployment Pctl                                    float64
# Housing Burden                                       float64
# Housing Burden Pctl                                  float64
# Pop. Char.                                           float64
# Pop. Char. Score                                     float64
# Pop. Char. Pctl                                      float64
# dtype: object

# %%
cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8035 entries, 0 to 8034
# Data columns (total 57 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Census Tract                                      8035 non-null   int64
#  1   Total Population                                  8035 non-null   int64
#  2   California County                                 8035 non-null   object
#  3   ZIP                                               8035 non-null   int64
#  4   Nearby City
# (to help approximate location only)  8035 non-null   object
#  5   Longitude                                         8035 non-null   float64
#  6   Latitude                                          8035 non-null   float64
#  7   CES 3.0 Score                                     7929 non-null   float64
#  8    CES 3.0 Percentile                               7929 non-null   float64
#  9   CES 3.0
# Percentile Range                         7929 non-null   object
#  10  SB 535 Disadvantaged Community                    8035 non-null   object
#  11  Ozone                                             8035 non-null   float64
#  12  Ozone Pctl                                        8035 non-null   float64
#  13  PM2.5                                             8016 non-null   float64
#  14  PM2.5 Pctl                                        8016 non-null   float64
#  15  Diesel PM                                         8035 non-null   float64
#  16  Diesel PM Pctl                                    8035 non-null   float64
#  17  Drinking Water                                    8017 non-null   float64
#  18  Drinking Water Pctl                               8017 non-null   float64
#  19  Pesticides                                        8035 non-null   float64
#  20  Pesticides Pctl                                   8035 non-null   float64
#  21  Tox. Release                                      8035 non-null   float64
#  22  Tox. Release Pctl                                 8035 non-null   float64
#  23  Traffic                                           7979 non-null   float64
#  24  Traffic Pctl                                      7979 non-null   float64
#  25  Cleanup Sites                                     8035 non-null   float64
#  26  Cleanup Sites Pctl                                8035 non-null   float64
#  27  Groundwater Threats                               8035 non-null   float64
#  28  Groundwater Threats Pctl                          8035 non-null   float64
#  29  Haz. Waste                                        8035 non-null   float64
#  30  Haz. Waste Pctl                                   8035 non-null   float64
#  31  Imp. Water Bodies                                 8035 non-null   int64
#  32  Imp. Water Bodies Pctl                            8035 non-null   float64
#  33  Solid Waste                                       8035 non-null   float64
#  34  Solid Waste Pctl                                  8035 non-null   float64
#  35  Pollution Burden                                  8035 non-null   float64
#  36  Pollution Burden Score                            8035 non-null   float64
#  37  Pollution Burden Pctl                             8035 non-null   float64
#  38  Asthma                                            8035 non-null   float64
#  39  Asthma Pctl                                       8035 non-null   float64
#  40  Low Birth Weight                                  7813 non-null   float64
#  41  Low Birth Weight Pctl                             7813 non-null   float64
#  42  Cardiovascular Disease                            8035 non-null   float64
#  43  Cardiovascular Disease Pctl                       8035 non-null   float64
#  44  Education                                         7939 non-null   float64
#  45  Education Pctl                                    7939 non-null   float64
#  46  Linguistic Isolation                              7793 non-null   float64
#  47  Linguistic Isolation Pctl                         7793 non-null   float64
#  48  Poverty                                           7956 non-null   float64
#  49  Poverty Pctl                                      7956 non-null   float64
#  50  Unemployment                                      7880 non-null   float64
#  51  Unemployment Pctl                                 7880 non-null   float64
#  52  Housing Burden                                    7878 non-null   float64
#  53  Housing Burden Pctl                               7878 non-null   float64
#  54  Pop. Char.                                        7929 non-null   float64
#  55  Pop. Char. Score                                  7929 non-null   float64
#  56  Pop. Char. Pctl                                   7929 non-null   float64
# dtypes: float64(49), int64(4), object(4)
# memory usage: 3.5+ MB

# %%
#cal.fillna(0, inplace=True)

# %%
cal.isna().sum()
# Out:
# Census Tract                                           0
# Total Population                                       0
# California County                                      0
# ZIP                                                    0
# Nearby City \n(to help approximate location only)      0
# Longitude                                              0
# Latitude                                               0
# CES 3.0 Score                                        106
#  CES 3.0 Percentile                                  106
# CES 3.0 \nPercentile Range                           106
# SB 535 Disadvantaged Community                         0
# Ozone                                                  0
# Ozone Pctl                                             0
# PM2.5                                                 19
# PM2.5 Pctl                                            19
# Diesel PM                                              0
# Diesel PM Pctl                                         0
# Drinking Water                                        18
# Drinking Water Pctl                                   18
# Pesticides                                             0
# Pesticides Pctl                                        0
# Tox. Release                                           0
# Tox. Release Pctl                                      0
# Traffic                                               56
# Traffic Pctl                                          56
# Cleanup Sites                                          0
# Cleanup Sites Pctl                                     0
# Groundwater Threats                                    0
# Groundwater Threats Pctl                               0
# Haz. Waste                                             0
# Haz. Waste Pctl                                        0
# Imp. Water Bodies                                      0
# Imp. Water Bodies Pctl                                 0
# Solid Waste                                            0
# Solid Waste Pctl                                       0
# Pollution Burden                                       0
# Pollution Burden Score                                 0
# Pollution Burden Pctl                                  0
# Asthma                                                 0
# Asthma Pctl                                            0
# Low Birth Weight                                     222
# Low Birth Weight Pctl                                222
# Cardiovascular Disease                                 0
# Cardiovascular Disease Pctl                            0
# Education                                             96
# Education Pctl                                        96
# Linguistic Isolation                                 242
# Linguistic Isolation Pctl                            242
# Poverty                                               79
# Poverty Pctl                                          79
# Unemployment                                         155
# Unemployment Pctl                                    155
# Housing Burden                                       157
# Housing Burden Pctl                                  157
# Pop. Char.                                           106
# Pop. Char. Score                                     106
# Pop. Char. Pctl                                      106
# dtype: int64

# %%
# drop some columns

# %%
import seaborn as sns

# %%
sns.boxplot(data = cal, x= 'Total Population')
# Out:
# <AxesSubplot:xlabel='Total Population'>

# %%
sns.scatterplot(x='Ozone', y = 'Total Population', data = cal)
# Out:
# <AxesSubplot:xlabel='Ozone', ylabel='Total Population'>

# %%
sns.scatterplot(x= 'Total Population', y ='Pesticides', data = cal, hue="SB 535 Disadvantaged Community")
# Out:
# <AxesSubplot:xlabel='Total Population', ylabel='Pesticides'>

# %%
sns.scatterplot(x= 'Total Population', y ='Pollution Burden', data = cal, hue="SB 535 Disadvantaged Community")
# Out:
# <AxesSubplot:xlabel='Total Population', ylabel='Pollution Burden'>

# %%
sns.scatterplot(x= 'Total Population', y ='Pollution Burden Pctl', data = cal, hue="SB 535 Disadvantaged Community")
# Out:
# <AxesSubplot:xlabel='Total Population', ylabel='Pollution Burden Pctl'>

# %%
sns.scatterplot(x= 'Total Population', y ='Cardiovascular Disease Pctl', data = cal, hue="SB 535 Disadvantaged Community")
# Out:
# <AxesSubplot:xlabel='Total Population', ylabel='Cardiovascular Disease Pctl'>

# %%
sns.scatterplot(x= 'Total Population', y ='Solid Waste Pctl', data = cal, hue="SB 535 Disadvantaged Community")
# Out:
# <AxesSubplot:xlabel='Total Population', ylabel='Solid Waste Pctl'>

# %%
sns.barplot(y ='Cardiovascular Disease Pctl', data = cal, x="SB 535 Disadvantaged Community")
# Out:
# <AxesSubplot:xlabel='SB 535 Disadvantaged Community', ylabel='Cardiovascular Disease Pctl'>

# %%
import matplotlib.pyplot as plt
sns.heatmap(cal.corr()[['Cardiovascular Disease Pctl']].drop(['Cardiovascular Disease Pctl','Longitude','Census Tract','Latitude']))

plt.show()

# %%
plt.subplots(1,1, figsize=(36,36))
sns.heatmap(cal.corr(), annot= True)
plt.show()

# %%
sns.histplot(data = cal, x = 'Ozone', y = 'Poverty', bins = 15, palette='rgb')
# Out:
# <AxesSubplot:xlabel='Ozone', ylabel='Poverty'>

# %%
sns.histplot(data = cal, x = 'Ozone', y = 'Asthma', bins = 15, palette='rgb')
# Out:
# <AxesSubplot:xlabel='Ozone', ylabel='Asthma'>

# %%
pct_missing = cal.isna().mean()
pct_missing
# Out:
# Census Tract                                         0.000000
# Total Population                                     0.000000
# California County                                    0.000000
# ZIP                                                  0.000000
# Nearby City \n(to help approximate location only)    0.000000
# Longitude                                            0.000000
# Latitude                                             0.000000
# CES 3.0 Score                                        0.013192
#  CES 3.0 Percentile                                  0.013192
# CES 3.0 \nPercentile Range                           0.013192
# SB 535 Disadvantaged Community                       0.000000
# Ozone                                                0.000000
# Ozone Pctl                                           0.000000
# PM2.5                                                0.002365
# PM2.5 Pctl                                           0.002365
# Diesel PM                                            0.000000
# Diesel PM Pctl                                       0.000000
# Drinking Water                                       0.002240
# Drinking Water Pctl                                  0.002240
# Pesticides                                           0.000000
# Pesticides Pctl                                      0.000000
# Tox. Release                                         0.000000
# Tox. Release Pctl                                    0.000000
# Traffic                                              0.006970
# Traffic Pctl                                         0.006970
# Cleanup Sites                                        0.000000
# Cleanup Sites Pctl                                   0.000000
# Groundwater Threats                                  0.000000
# Groundwater Threats Pctl                             0.000000
# Haz. Waste                                           0.000000
# Haz. Waste Pctl                                      0.000000
# Imp. Water Bodies                                    0.000000
# Imp. Water Bodies Pctl                               0.000000
# Solid Waste                                          0.000000
# Solid Waste Pctl                                     0.000000
# Pollution Burden                                     0.000000
# Pollution Burden Score                               0.000000
# Pollution Burden Pctl                                0.000000
# Asthma                                               0.000000
# Asthma Pctl                                          0.000000
# Low Birth Weight                                     0.027629
# Low Birth Weight Pctl                                0.027629
# Cardiovascular Disease                               0.000000
# Cardiovascular Disease Pctl                          0.000000
# Education                                            0.011948
# Education Pctl                                       0.011948
# Linguistic Isolation                                 0.030118
# Linguistic Isolation Pctl                            0.030118
# Poverty                                              0.009832
# Poverty Pctl                                         0.009832
# Unemployment                                         0.019291
# Unemployment Pctl                                    0.019291
# Housing Burden                                       0.019540
# Housing Burden Pctl                                  0.019540
# Pop. Char.                                           0.013192
# Pop. Char. Score                                     0.013192
# Pop. Char. Pctl                                      0.013192
# dtype: float64

# %%
X = cal[['Total Population', 'Poverty', 'Education', 'Pollution Burden', 'Solid Waste', 
       'Haz. Waste', 'Traffic', 'Pesticides', 'Diesel PM', 'Ozone', 'SB 535 Disadvantaged Community']]
y = cal['Asthma Pctl']

# %%
X=pd.get_dummies(X)
X=X.fillna(X.median()) #fill with median value

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y,random_state= 42, test_size=.2)

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr.fit(X_train, y_train)
# Out:
# SVR()

# %%
train_preds =  svr.predict(X_train)
test_preds= svr.predict(X_test)

# %%
print(f'Train error: {mean_squared_error(y_train,train_preds)}')
print(f'Test error: {mean_squared_error(y_test,test_preds)}')

svr.score(X_train,y_train)
# Out:
# Train error: 821.9403587982769
# Test error: 840.5983562811261
# 0.012699720090386335

# %%
cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8035 entries, 0 to 8034
# Data columns (total 57 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Census Tract                                      8035 non-null   int64
#  1   Total Population                                  8035 non-null   int64
#  2   California County                                 8035 non-null   object
#  3   ZIP                                               8035 non-null   int64
#  4   Nearby City
# (to help approximate location only)  8035 non-null   object
#  5   Longitude                                         8035 non-null   float64
#  6   Latitude                                          8035 non-null   float64
#  7   CES 3.0 Score                                     7929 non-null   float64
#  8    CES 3.0 Percentile                               7929 non-null   float64
#  9   CES 3.0
# Percentile Range                         7929 non-null   object
#  10  SB 535 Disadvantaged Community                    8035 non-null   object
#  11  Ozone                                             8035 non-null   float64
#  12  Ozone Pctl                                        8035 non-null   float64
#  13  PM2.5                                             8016 non-null   float64
#  14  PM2.5 Pctl                                        8016 non-null   float64
#  15  Diesel PM                                         8035 non-null   float64
#  16  Diesel PM Pctl                                    8035 non-null   float64
#  17  Drinking Water                                    8017 non-null   float64
#  18  Drinking Water Pctl                               8017 non-null   float64
#  19  Pesticides                                        8035 non-null   float64
#  20  Pesticides Pctl                                   8035 non-null   float64
#  21  Tox. Release                                      8035 non-null   float64
#  22  Tox. Release Pctl                                 8035 non-null   float64
#  23  Traffic                                           7979 non-null   float64
#  24  Traffic Pctl                                      7979 non-null   float64
#  25  Cleanup Sites                                     8035 non-null   float64
#  26  Cleanup Sites Pctl                                8035 non-null   float64
#  27  Groundwater Threats                               8035 non-null   float64
#  28  Groundwater Threats Pctl                          8035 non-null   float64
#  29  Haz. Waste                                        8035 non-null   float64
#  30  Haz. Waste Pctl                                   8035 non-null   float64
#  31  Imp. Water Bodies                                 8035 non-null   int64
#  32  Imp. Water Bodies Pctl                            8035 non-null   float64
#  33  Solid Waste                                       8035 non-null   float64
#  34  Solid Waste Pctl                                  8035 non-null   float64
#  35  Pollution Burden                                  8035 non-null   float64
#  36  Pollution Burden Score                            8035 non-null   float64
#  37  Pollution Burden Pctl                             8035 non-null   float64
#  38  Asthma                                            8035 non-null   float64
#  39  Asthma Pctl                                       8035 non-null   float64
#  40  Low Birth Weight                                  7813 non-null   float64
#  41  Low Birth Weight Pctl                             7813 non-null   float64
#  42  Cardiovascular Disease                            8035 non-null   float64
#  43  Cardiovascular Disease Pctl                       8035 non-null   float64
#  44  Education                                         7939 non-null   float64
#  45  Education Pctl                                    7939 non-null   float64
#  46  Linguistic Isolation                              7793 non-null   float64
#  47  Linguistic Isolation Pctl                         7793 non-null   float64
#  48  Poverty                                           7956 non-null   float64
#  49  Poverty Pctl                                      7956 non-null   float64
#  50  Unemployment                                      7880 non-null   float64
#  51  Unemployment Pctl                                 7880 non-null   float64
#  52  Housing Burden                                    7878 non-null   float64
#  53  Housing Burden Pctl                               7878 non-null   float64
#  54  Pop. Char.                                        7929 non-null   float64
#  55  Pop. Char. Score                                  7929 non-null   float64
#  56  Pop. Char. Pctl                                   7929 non-null   float64
# dtypes: float64(49), int64(4), object(4)
# memory usage: 3.5+ MB

# %%
X = cal[['CES 3.0 Score', 'Low Birth Weight', 'Cardiovascular Disease', 'Education', 'Linguistic Isolation', 'Poverty', 'Unemployment', 'Housing Burden']]
y = cal['Asthma Pctl']

# %%
X=pd.get_dummies(X)
X=X.fillna(X.median())

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y,random_state= 42, test_size=.2)

# %%
svr = SVR()
svr.fit(X_train, y_train)
# Out:
# SVR()

# %%
train_preds =  svr.predict(X_train)
test_preds= svr.predict(X_test)

# %%
print(f'Train error: {mean_squared_error(y_train,train_preds)}')
print(f'Test error: {mean_squared_error(y_test,test_preds)}')

svr.score(X_train,y_train)
# Out:
# Train error: 352.37896448959117
# Test error: 356.5166644680112
# 0.5767285952675592

# %%
X = cal[['CES 3.0 Score', 'Low Birth Weight', 'Cardiovascular Disease', 'Education', 'Linguistic Isolation', 'Poverty', 'Unemployment', 'Housing Burden']]
y = cal['Asthma Pctl']

# %%
X=pd.get_dummies(X)
X=X.fillna(X.median())

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y,random_state= 42, test_size=.2)

# %%
from sklearn.linear_model import Lasso

# %%
las = Lasso()
las.fit(X_train, y_train)
# Out:
# Lasso()

# %%
train_preds =  las.predict(X_train)
test_preds= las.predict(X_test)

# %%
print(f'Train error: {mean_squared_error(y_train,train_preds)}')
print(f'Test error: {mean_squared_error(y_test,test_preds)}')

las.score(X_train,y_train)
# Out:
# Train error: 334.47872655648945
# Test error: 328.0866835713292
# 0.5982300457470547

# %%
X = cal[['CES 3.0 Score', 'Low Birth Weight', 'Cardiovascular Disease', 'Education', 'Linguistic Isolation', 'Poverty', 'Unemployment', 'Housing Burden']]
y = cal['Asthma Pctl']

# %%
X=pd.get_dummies(X)
X=X.fillna(X.median())

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y,random_state= 42, test_size=.2)

# %%
from sklearn.linear_model import Ridge

# %%
rid = Ridge()
rid.fit(X_train, y_train)
# Out:
# Ridge()

# %%
train_preds =  rid.predict(X_train)
test_preds= rid.predict(X_test)

# %%
print(f'Train error: {mean_squared_error(y_train,train_preds)}')
print(f'Test error: {mean_squared_error(y_test,test_preds)}')

rid.score(X_train,y_train)
# Out:
# Train error: 333.792290399288
# Test error: 326.26871194297405
# 0.5990545807670116

# %%
# cal is enviroscreen 3
cal['origin']= '2018 update'
cal2 = pd.read_csv('../../raw_data/calenviroscreen2-final-report.csv')
cal2['origin']='2019 update'

# %%
cal4 = pd.read_excel('../../raw_data/calenviroscreen40resultsdatadictionary_F_2021.xlsx')
cal4['origin']= '2021 update'

# %%
cal1 = pd.read_excel('../../raw_data/calenviroscreendatav11.xls')
cal1['origin']= '2017 update'

# %%
all_enviro = pd.concat([cal, cal2, cal4, cal1])

# %%
pd.set_option('display.max_rows',30)

# %%
all_enviro.isnull().sum()
# Out:
# Total Population    0
# Ozone               0
# Ozone Pctl          0
# PM2.5               0
# PM2.5 Pctl          0
#                    ..
# Poverty             0
# Poverty Pctl        0
# Pop. Char.          0
# Pop. Char. Score    0
# origin              0
# Length: 36, dtype: int64

# %%
group1 = set(cal1.columns).intersection(set(cal.columns))

# %%
group2 = set(cal2.columns).intersection(set(cal4.columns))

# %%
shared_columns=group1.intersection(group2)
shared_columns
# Out:
# {'Asthma',
#  'Asthma Pctl',
#  'Cleanup Sites',
#  'Cleanup Sites Pctl',
#  'Diesel PM',
#  'Diesel PM Pctl',
#  'Education',
#  'Education Pctl',
#  'Groundwater Threats',
#  'Groundwater Threats Pctl',
#  'Haz. Waste',
#  'Haz. Waste Pctl',
#  'Imp. Water Bodies',
#  'Imp. Water Bodies Pctl',
#  'Linguistic Isolation',
#  'Linguistic Isolation Pctl',
#  'Low Birth Weight',
#  'Low Birth Weight Pctl',
#  'Ozone',
#  'Ozone Pctl',
#  'PM2.5',
#  'PM2.5 Pctl',
#  'Pesticides',
#  'Pesticides Pctl',
#  'Pollution Burden',
#  'Pollution Burden Score',
#  'Pop. Char. ',
#  'Pop. Char. Score',
#  'Poverty',
#  'Poverty Pctl',
#  'Solid Waste',
#  'Solid Waste Pctl',
#  'Total Population',
#  'Traffic',
#  'Traffic Pctl',
#  'origin'}

# %%
all_enviro=all_enviro[all_enviro.columns[all_enviro.columns.isin(shared_columns)]]

# %%
all_enviro.head()
# Out:
#    Total Population  Ozone  Ozone Pctl  PM2.5  PM2.5 Pctl  Diesel PM  \
# 0              3174  0.065       98.18  15.40       97.22     48.524
# 1              6133  0.062       91.10  13.31       93.64     38.556
# 2              3167  0.062       91.10  15.40       97.22     47.445
# 3              6692  0.046       53.02  12.54       84.02     24.117
# 4              2206  0.065       98.18  15.40       97.22     18.846
#
#    Diesel PM Pctl  Pesticides  Pesticides Pctl  Traffic  ...  \
# 0           95.54        2.75            47.82   909.14  ...
# 1           92.12        1.37            41.34   782.26  ...
# 2           95.42        3.03            48.75   576.52  ...
# 3           73.52       12.93            60.56  1305.01  ...
# 4           58.22     3518.41            95.15   435.16  ...
#
#    Low Birth Weight Pctl  Education  Education Pctl  Linguistic Isolation  \
# 0                  93.84       53.3           95.76                  16.2
# 1                  90.85       53.3           95.76                  33.4
# 2                  99.78       42.3           89.06                  16.7
# 3                  80.65       40.8           87.52                  15.3
# 4                  38.92       45.1           91.13                  14.7
#
#    Linguistic Isolation Pctl  Poverty  Poverty Pctl  Pop. Char.   \
# 0                      77.51     76.3         97.12        92.12
# 1                      96.25     72.5         94.63        87.44
# 2                      78.39     86.8         99.56        94.58
# 3                      75.14     61.3         85.57        86.70
# 4                      73.72     66.4         90.23        80.08
#
#    Pop. Char. Score       origin
# 0              9.55  2018 update
# 1              9.07  2018 update
# 2              9.81  2018 update
# 3              8.99  2018 update
# 4              8.30  2018 update
#
# [5 rows x 36 columns]

# %%
all_enviro.isnull().sum()
# Out:
# Total Population                0
# Ozone                         203
# Ozone Pctl                    203
# PM2.5                         246
# PM2.5 Pctl                    246
# Diesel PM                       0
# Diesel PM Pctl                  0
# Pesticides                      0
# Pesticides Pctl                 0
# Traffic                        91
# Traffic Pctl                   91
# Cleanup Sites                   0
# Cleanup Sites Pctl              0
# Groundwater Threats             0
# Groundwater Threats Pctl        0
# Haz. Waste                      0
# Haz. Waste Pctl                 0
# Imp. Water Bodies               0
# Imp. Water Bodies Pctl          0
# Solid Waste                     0
# Solid Waste Pctl                0
# Pollution Burden                0
# Pollution Burden Score          0
# Asthma                        155
# Asthma Pctl                   155
# Low Birth Weight              977
# Low Birth Weight Pctl         977
# Education                     364
# Education Pctl                364
# Linguistic Isolation         1389
# Linguistic Isolation Pctl    1389
# Poverty                       397
# Poverty Pctl                  397
# Pop. Char.                    281
# Pop. Char. Score              281
# origin                          0
# dtype: int64

# %%
all_enviro.dropna(inplace=True)
# Out:
# /Users/mashyman/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
all_enviro.isnull().sum()
# Out:
# Total Population    0
# Ozone               0
# Ozone Pctl          0
# PM2.5               0
# PM2.5 Pctl          0
#                    ..
# Poverty             0
# Poverty Pctl        0
# Pop. Char.          0
# Pop. Char. Score    0
# origin              0
# Length: 36, dtype: int64

# %%
all_enviro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23880 entries, 0 to 1709
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Total Population           23880 non-null  int64
#  1   Ozone                      23880 non-null  float64
#  2   Ozone Pctl                 23880 non-null  float64
#  3   PM2.5                      23880 non-null  float64
#  4   PM2.5 Pctl                 23880 non-null  float64
#  5   Diesel PM                  23880 non-null  float64
#  6   Diesel PM Pctl             23880 non-null  float64
#  7   Pesticides                 23880 non-null  float64
#  8   Pesticides Pctl            23880 non-null  float64
#  9   Traffic                    23880 non-null  float64
#  10  Traffic Pctl               23880 non-null  float64
#  11  Cleanup Sites              23880 non-null  float64
#  12  Cleanup Sites Pctl         23880 non-null  float64
#  13  Groundwater Threats        23880 non-null  float64
#  14  Groundwater Threats Pctl   23880 non-null  float64
#  15  Haz. Waste                 23880 non-null  float64
#  16  Haz. Waste Pctl            23880 non-null  float64
#  17  Imp. Water Bodies          23880 non-null  int64
#  18  Imp. Water Bodies Pctl     23880 non-null  float64
#  19  Solid Waste                23880 non-null  float64
#  20  Solid Waste Pctl           23880 non-null  float64
#  21  Pollution Burden           23880 non-null  float64
#  22  Pollution Burden Score     23880 non-null  float64
#  23  Asthma                     23880 non-null  float64
#  24  Asthma Pctl                23880 non-null  float64
#  25  Low Birth Weight           23880 non-null  float64
#  26  Low Birth Weight Pctl      23880 non-null  float64
#  27  Education                  23880 non-null  float64
#  28  Education Pctl             23880 non-null  float64
#  29  Linguistic Isolation       23880 non-null  float64
#  30  Linguistic Isolation Pctl  23880 non-null  float64
#  31  Poverty                    23880 non-null  float64
#  32  Poverty Pctl               23880 non-null  float64
#  33  Pop. Char.                 23880 non-null  float64
#  34  Pop. Char. Score           23880 non-null  float64
#  35  origin                     23880 non-null  object
# dtypes: float64(33), int64(2), object(1)
# memory usage: 6.7+ MB

# %%
all_enviro.to_csv('All_enviroscreen_data.csv')

# %%
df1 = pd.DataFrame(all_enviro)

# %%
df1['origin'].value_counts(normalize=True)
# Out:
# 2018 update    0.318719
# 2019 update    0.317085
# 2021 update    0.316206
# 2017 update    0.047990
# Name: origin, dtype: float64
